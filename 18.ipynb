# %% [markdown]
# <a href="https://colab.research.google.com/github/FilippMakarov/chekFM/blob/main/18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('spotify-data.csv')

# %%
data.isnull() # поиск пустых ячеек
# Out:
#            id   name  artists  duration_ms  release_date   year  acousticness  \
# 0       False  False    False        False         False  False         False
# 1       False  False    False        False         False  False         False
# 2       False  False    False        False         False  False         False
# 3       False  False    False        False         False  False         False
# 4       False  False    False        False         False  False         False
# ...       ...    ...      ...          ...           ...    ...           ...
# 169904  False  False    False        False         False  False         False
# 169905  False  False    False        False         False  False         False
# 169906  False  False    False        False         False  False         False
# 169907  False  False    False        False         False  False         False
# 169908  False  False    False        False         False  False         False
#
# ...

# %% [markdown]
# Пустых ячеек не найдено

# %%
data.corr() # оценка корреляции
# Out:
# <ipython-input-57-924271c42a44>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr() # оценка корреляции
#                   duration_ms      year  acousticness  danceability    energy  \
# duration_ms          1.000000  0.076293     -0.079311     -0.134500  0.036396
# year                 0.076293  1.000000     -0.624550      0.203430  0.532419
# acousticness        -0.079311 -0.624550      1.000000     -0.265950 -0.750283
# danceability        -0.134500  0.203430     -0.265950      1.000000  0.220569
# energy               0.036396  0.532419     -0.750283      0.220569  1.000000
# instrumentalness     0.084814 -0.291571      0.335821     -0.281429 -0.287692
# liveness             0.034270 -0.055839     -0.023871     -0.105532  0.126293
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = data.corr()

kot = corr[corr>=.1]
plt.figure(figsize=(6,4))
sns.heatmap(kot, cmap="Greens")
# Out:
# <ipython-input-58-ac440af31eaf>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <Axes: >

# %% [markdown]
# Таким образом, наибольшая положительная корреляция  отмечается между столбцами:year-popularity, energy-loundness/

# %%
data["tempo"].loc[0:5].sum() # сумма значений в столбце tempo с 0 по 5 строку
# Out:
# 543.2909999999999

# %%
data["mode"].loc[5:55].mean() # среднее значение в столбце mode в диапазоне строк с 5 по 55
# Out:
# 0.6470588235294118

# %%
data["valence"].loc[0:100].median() # медиана для столбца valence в диапазоне строк от 0 до 100
# Out:
# 0.511

# %%
data["valence"].loc[0:100].min() # минимум для столбца valence в диапазоне строк от 0 до 100
# Out:
# 0.0379

# %%
data["valence"].loc[0:100].max() # максимум для столбца valence в диапазоне строк от 0 до 100
# Out:
# 0.976

# %%
data["valence"].loc[0:100].std() # стандартное отклонение для столбца valence в диапазоне строк от 0 до 100
# Out:
# 0.29376660008035677

# %% [markdown]
# Операции сравнения датафреймов

# %%
df1 = data[["tempo","valence"]].loc[0:5] # создадим датафрейм 1
df2 = data[["danceability","energy"]].loc[0:5] # создадим датафрейм 2

# %%
df1
# Out:
#      tempo  valence
# 0  118.469   0.7790
# 1   83.972   0.0767
# 2  107.177   0.8800
# 3  108.003   0.7200
# 4   62.149   0.0693
# 5   63.521   0.2660

# %%
df2
# Out:
#    danceability  energy
# 0         0.708  0.1950
# 1         0.379  0.0135
# 2         0.749  0.2200
# 3         0.781  0.1300
# 4         0.210  0.2040
# 5         0.424  0.1200

# %%
print (df1>=df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-c5e1c9c553ab> in <cell line: 1>()
# ----> 1 print (df1>=df2)
#       2
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __ge__(self, other)
#      60     @unpack_zerodim_and_defer("__ge__")
#      61     def __ge__(self, other):
# ---> 62         return self._cmp_method(other, operator.ge)
#      63
#      64     # -------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    7577         axis = 1  # only relevant for Series other case
#    7578
# ...

# %%
df1[df1 >1]
# Out:
#      tempo  valence
# 0  118.469      NaN
# 1   83.972      NaN
# 2  107.177      NaN
# 3  108.003      NaN
# 4   62.149      NaN
# 5   63.521      NaN

# %%
df2[(df2 < 0.5) & (df2 >0)]
# Out:
#    danceability  energy
# 0           NaN  0.1950
# 1         0.379  0.0135
# 2           NaN  0.2200
# 3           NaN  0.1300
# 4         0.210  0.2040
# 5         0.424  0.1200
